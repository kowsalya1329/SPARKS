# %%
SPARKS FOUNDATION  - GRIPAPRIL21

TASK 1- PREDICTION USING SUPERVISED MACHINE LEARNING

AUTHOR:KOWSALYA.G

# %%
# Importing all libraries required 
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data 

url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(6)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20

# %%
#Plot the data points on 2-D graph 


# Plotting the distribution of scores
s_data.plot(x='Hours', y='Scores', style='o',c="orange")  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
#Preparing the data

X = s_data.iloc[:, :-1].values  
y = s_data.iloc[:, 1].values  
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line

line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y,color="red")
plt.plot(X, line,c="black");
plt.show()

# %%
#predictions

print(X_test) 
y_pred = regressor.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
Output=regressor.predict(X_test)
print(Output)
# Out:
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
hours =np.array([[9.25]]) 
own_pred = regressor.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted score if a student studies for 9.25 hrs/ =" , format(own_pred[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted score if a student studies for 9.25 hrs/ = 93.69173248737535

# %%
#MODEL EVALUATION


from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002975
